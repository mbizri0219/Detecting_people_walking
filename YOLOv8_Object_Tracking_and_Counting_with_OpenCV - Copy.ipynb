# %% [markdown]
# # Object Tracking

# %%
#uncomment these for when you want to create an environment on first use
#make sure to use the v100 GPu with high ram on
#!conda create -n ankan python=3.9.0
#!conda activate ankan
# !conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
# !pip install ultralytics
# !pip install opencv-python
# !pip install jupyterlab
# Out:
# /bin/bash: line 1: conda: command not found
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.4/750.4 kB 7.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %% [markdown]
# **you have to go to pytorch [website](https://pytorch.org/get-started/locally/) to install your preferable cuda version.**

# %% [markdown]
# ### Library Imports

# %%
import cv2
from ultralytics import YOLO
import torch
import numpy as np

# %% [markdown]
# ## Tracking with Official YOLOv8 Model

# %%
# Load an official or custom model
model = YOLO('yolov8x.pt')  # Load an official Detect model

# Perform tracking with the model
results = model.track(source="/content/sample_data/people_walking_1.mp4", show=False, save=True, name='output_dir_name', persist=True, classes=1)  # Tracking with default tracker
#results = model.track(source="https://youtu.be/LNwODJXcvt4", show=True, tracker="bytetrack.yaml")  # Tracking with ByteTrack tracker
# Out:
# ...
# 100%|██████████| 131M/131M [00:02<00:00, 51.2MB/s]
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 5.3s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...

# %% [markdown]
# # Object Counting

# %% [markdown]
# ## Whole Frame based Counting

# %% [markdown]
# ## Set up the Environment

# %%
# Clone Ultralytics repo
# !git clone https://github.com/ultralytics/ultralytics

# Navigate to the local directory
# !cd /content/ultralytics/examples/YOLOv8-Region-Counter
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 24119, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (183/183), done.
# remote: Total 24119 (delta 111), reused 114 (delta 44), pack-reused 23892
# Receiving objects: 100% (24119/24119), 14.30 MiB | 5.63 MiB/s, done.
# Resolving deltas: 100% (16936/16936), done.

# %% [markdown]
# ### Now You have to go to the `ultralytics/examples/YOLOv8-Region-Counter/yolov8_region_counter.py` and replace the updated `yolov8_region_counter.py` file provided.

# %% [markdown]
# ## Run Inference

# %%
# Run Inference on Official/Custom Models
#make sure you are using the v100 gpu available in runtime/manage sessions on tool
# !python /content/ultralytics/examples/YOLOv8-Region-Counter/yolov8_region_counter.py --source "/content/sample_data/people_walking.mp4" --weights "/content/yolov8x.pt" --view-img --save-img --classes 2

#This is where the save results to text file would go
# Save results to a text file
#with open('tracking_results.txt', 'w') as f:
    #f.write(str(results))
# Out:
# 0: 384x640 (no detections), 670.8ms
# Speed: 4.8ms preprocess, 670.8ms inference, 1459.5ms postprocess per image at shape (1, 3, 384, 640)
# qt.qpa.xcb: could not connect to display
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "/usr/local/lib/python3.10/dist-packages/cv2/qt/plugins" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: xcb.
